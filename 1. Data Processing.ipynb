# %%
# Import all the things...
# import numpy as np
import pandas as pd
from pathlib import Path
from utils.data_processing import (
    clean_data,
    null_strings,
    is_valid_child,
    column_categories,
    geocode_df,
    validate_neighborhood_data,
    prepare_additional_features,
)

# %%
# null_strings = ['(null)','#N/A', 'NA', '?', '', ' ', '&&', 'nan']

path = Path('./data/raw')
csv_files = path.glob('*.csv')

raw_df = pd.concat((pd.read_csv(f,dtype={
        'STOP_FRISK_DATE': 'object',  # Keep as string
        'STOP_FRISK_TIME': 'object'   # Keep as string
    },
    na_values=null_strings,  # Standardize nulls
    low_memory=False) for f in csv_files), ignore_index=True)
raw_df.head()
# Out:
#    STOP_ID STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2   MONTH2    DAY2  \
# 0        1      2021-01-01        01:50:00   2021  January  Friday
# 1        2      2021-01-01        10:55:00   2021  January  Friday
# 2        3      2021-01-01        10:10:00   2021  January  Friday
# 3        4      2021-01-01        20:17:00   2021  January  Friday
# 4        5      2021-01-01        19:59:00   2021  January  Friday
#
#       STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 0  Based on C/W on Scene                APP                  SGT
# 1     Based on Radio Run                APP                  POM
# 2  Based on C/W on Scene                APP                  POM
# 3  Based on C/W on Scene                APP                  POM
# 4     Based on Radio Run                APP                  POM
#
#    ISSUING_OFFICER_COMMAND_CODE  ... SUSPECT_OTHER_DESCRIPTION  \
# 0                            42  ...                       NaN
# 1                           105  ...                       NaN
# 2                           106  ...            YELLOW SWEATER
# 3                            83  ...                       NaN
# 4                            26  ...                   UNKNOWN
#
#    STOP_LOCATION_PRECINCT STOP_LOCATION_SECTOR_CODE STOP_LOCATION_APARTMENT  \
# 0                    42.0                         B                      2C
# 1                   105.0                         B                     NaN
# 2                   106.0                         A                     NaN
# 3                    73.0                         A                     NaN
# 4                    26.0                         C                      4D
#
#   STOP_LOCATION_FULL_ADDRESS STOP_LOCATION_STREET_NAME  STOP_LOCATION_X  \
# 0            850 JENNINGS ST               JENNINGS ST        1013737.0
# 1          219 ST && 139 AVE                    219 ST        1052511.0
# 2           151 AVE && 84 ST                   151 AVE        1025662.0
# 3  BROADWAY && MAC DOUGAL ST                  BROADWAY        1010122.0
# 4               439 W 125 ST                  W 125 ST         996623.0
#
#   STOP_LOCATION_Y  STOP_LOCATION_PATROL_BORO_NAME STOP_LOCATION_BORO_NAME
# 0        242476.0                            PBBX                   BRONX
# 1        184460.0                            PBQS                  QUEENS
# 2        182632.0                            PBQS                  QUEENS
# 3        187312.0                            PBBN                BROOKLYN
# 4        235311.0                            PBMN               MANHATTAN
#
# [5 rows x 83 columns]

# %%
cleaned_df = clean_data(raw_df, column_categories)
print(f'Approximately {(len(cleaned_df)/ len(raw_df)*100):.2f}% of the original data after cleaning')


plausible_df = cleaned_df[
    (cleaned_df.apply(is_valid_child, axis=1))
]
print(f'{(len(plausible_df) / len(cleaned_df)*100):.2f}% of data remains after age-height validation of children')
# Out:
# Approximately 83.02% of the original data after cleaning
# 99.96% of data remains after age-height validation of children

# %%
geocoded_df = geocode_df(plausible_df)
# Out:
# NTA CRS: EPSG:4326
# Stops GDF CRS: EPSG:4326
# NTA CRS: EPSG:4326
# Sample of transformed coordinates:
#          lat        lon
# 0  40.832167 -73.893445
# 1  40.672714 -73.753920
# 3  40.680767 -73.906721
# 4  40.812541 -73.955302
# 5  40.833561 -73.895933
# Points outside expected NYC bounds: 20
# Unmatched points: 26 out of 55073 (0.05%)
# Unmatched points remaining after cleaning: 0 out of 55047 (0.00%)

# %%
validate_neighborhood_data(geocoded_df)
# Out:
# Warning: No validation rule for Holy Cross Cemetery
# Warning: No validation rule for St. Michael's Cemetery
# Warning: No validation rule for Mount Olivet & All Faiths Cemeteries
# Warning: No validation rule for Rockaway Community Park
# Warning: No validation rule for Ferry Point Park-St. Raymond Cemetery
# All neighborhood-borough mappings validated successfully!
# Unique missing NTAs: {'Mount Olivet & All Faiths Cemeteries', "St. Michael's Cemetery", 'Holy Cross Cemetery', 'Rockaway Community Park', 'Ferry Point Park-St. Raymond Cemetery'}
# Found 23 borough name mismatches:
#       STOP_ID                                ntaname STOP_LOCATION_BORO_NAME  \
# 590       591                Howard Beach-Lindenwood                BROOKLYN
# 1993     1994                             Ozone Park                BROOKLYN
# 1994     1995                             Ozone Park                BROOKLYN
# 4126     4127                        Bushwick (East)                  QUEENS
# 4919     4920  Flatbush (West)-Ditmas Park-Parkville                  QUEENS
#
#       boroname
# 590     Queens
# 1993    Queens
# 1994    Queens
# 4126  Brooklyn
# 4919  Brooklyn
# After cleaning: Found 0 borough name mismatches:
# Empty DataFrame
# Columns: [STOP_ID, ntaname, STOP_LOCATION_BORO_NAME, boroname]
# Index: []

# %%
final_df = prepare_additional_features(geocoded_df)
final_df.info()
# Out:
# OUTCOME_OF_STOP
# No Charges Filed    34939
# Arrested            18501
# Summoned             1607
# Name: count, dtype: int64
# OFFICER_USED_FORCE
# False                 41203
# True                  13844
# Name: count, dtype: int64
# FORCE_TYPE
# No Force                41203
# Handcuffs                8891
# Firearm Drawn            2184
# Restraint Used           1241
# Other Physical Force     1199
# Taser                     303
# Weapon Impact              21
# Pepper Spray                5
# Name: count, dtype: int64
#       STOP_FRISK_DATE  STOP_ID  OBSERVED_DURATION_MINUTES  \
# 0 2021-01-01 00:01:00        1                          0
# 1 2021-01-01 00:01:00        2                          1
# 2 2021-01-01 00:01:00        4                          1
# 3 2021-01-01 00:01:00        5                          1
# 4 2021-01-01 00:01:00        6                          0
#
#    STOP_DURATION_MINUTES  SUSPECT_REPORTED_AGE  SUSPECT_WEIGHT  \
# 0                      2                    40             200
# 1                     10                    19             160
# 2                      5                    28             180
# 3                     30                    19             185
# 4                      6                    32             160
#
#    STOP_LOCATION_X  STOP_LOCATION_Y   MONTH2     STOP_WAS_INITIATED  ...  \
# 0          1013737           242476  January  Based on C/W on Scene  ...
# 1          1052511           184460  January     Based on Radio Run  ...
# 2          1010122           187312  January  Based on C/W on Scene  ...
# 3           996623           235311  January     Based on Radio Run  ...
# 4          1013048           242983  January     Based on Radio Run  ...
#
#     boroname ntatype nta2020 borocode countyfips   ntaabbrev cdta2020  \
# 0      Bronx       0  BX0303        2        005  CrtnaPkEst     BX03
# 1     Queens       0  QN1305        4        081       Lrltn     QN13
# 2   Brooklyn       0  BK1601        3        047       OcnHl     BK16
# 3  Manhattan       0  MN0901        1        061   MrngsdHts     MN09
# 4      Bronx       0  BX0303        2        005  CrtnaPkEst     BX03
#
#     OUTCOME_OF_STOP OFFICER_USED_FORCE FORCE_TYPE
# 0          Arrested               True  Handcuffs
# 1          Arrested              False   No Force
# 2  No Charges Filed              False   No Force
# 3  No Charges Filed               True  Handcuffs
# 4          Arrested              False   No Force
#
# [5 rows x 70 columns]

# %%
final_df.to_csv('./data/processed/stop-and-frisk.csv')
final_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 55047 entries, 0 to 55046
# Data columns (total 70 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STOP_FRISK_DATE                         42029 non-null  datetime64[ns]
#  1   STOP_ID                                 55047 non-null  Int64
#  2   OBSERVED_DURATION_MINUTES               55047 non-null  Int64
#  3   STOP_DURATION_MINUTES                   55047 non-null  Int64
#  4   SUSPECT_REPORTED_AGE                    55047 non-null  Int64
#  5   SUSPECT_WEIGHT                          54113 non-null  Int64
#  6   STOP_LOCATION_X                         55047 non-null  Int64
#  7   STOP_LOCATION_Y                         55047 non-null  Int64
#  8   MONTH2                                  55047 non-null  object
#  9   STOP_WAS_INITIATED                      55047 non-null  object
#  10  ISSUING_OFFICER_RANK                    55047 non-null  object
#  11  SUPERVISING_OFFICER_RANK                53393 non-null  object
#  12  JURISDICTION_DESCRIPTION                30174 non-null  object
#  13  SUSPECT_ARREST_OFFENSE                  18501 non-null  object
#  14  SUMMONS_OFFENSE_DESCRIPTION             1829 non-null   object
#  15  SUSPECTED_CRIME_DESCRIPTION             55047 non-null  object
#  16  DEMEANOR_OF_PERSON_STOPPED              48311 non-null  object
#  17  SUSPECT_SEX                             54922 non-null  object
#  18  SUSPECT_RACE_DESCRIPTION                55047 non-null  object
#  19  SUSPECT_BODY_BUILD_TYPE                 53993 non-null  object
#  20  SUSPECT_OTHER_DESCRIPTION               21660 non-null  object
#  21  STOP_LOCATION_BORO_NAME                 55047 non-null  object
#  22  OFFICER_EXPLAINED_STOP_FLAG             55047 non-null  boolean
#  23  OTHER_PERSON_STOPPED_FLAG               55047 non-null  boolean
#  24  SUSPECT_ARRESTED_FLAG                   55047 non-null  boolean
#  25  SUMMONS_ISSUED_FLAG                     55047 non-null  boolean
#  26  OFFICER_IN_UNIFORM_FLAG                 55047 non-null  boolean
#  27  FRISKED_FLAG                            55047 non-null  boolean
#  28  SEARCHED_FLAG                           55047 non-null  boolean
#  29  ASK_FOR_CONSENT_FLG                     54201 non-null  boolean
#  30  CONSENT_GIVEN_FLG                       45655 non-null  boolean
#  31  OTHER_CONTRABAND_FLAG                   55047 non-null  boolean
#  32  FIREARM_FLAG                            55047 non-null  boolean
#  33  KNIFE_CUTTER_FLAG                       55047 non-null  boolean
#  34  OTHER_WEAPON_FLAG                       55047 non-null  boolean
#  35  WEAPON_FOUND_FLAG                       55047 non-null  boolean
#  36  PHYSICAL_FORCE_CEW_FLAG                 55047 non-null  boolean
#  37  PHYSICAL_FORCE_DRAW_POINT_FIREARM_FLAG  55047 non-null  boolean
#  38  PHYSICAL_FORCE_HANDCUFF_SUSPECT_FLAG    55047 non-null  boolean
#  39  PHYSICAL_FORCE_OC_SPRAY_USED_FLAG       55047 non-null  boolean
#  40  PHYSICAL_FORCE_OTHER_FLAG               55047 non-null  boolean
#  41  PHYSICAL_FORCE_RESTRAINT_USED_FLAG      55047 non-null  boolean
#  42  PHYSICAL_FORCE_VERBAL_INSTRUCTION_FLAG  55047 non-null  boolean
#  43  PHYSICAL_FORCE_WEAPON_IMPACT_FLAG       55047 non-null  boolean
#  44  SEARCH_BASIS_ADMISSION_FLAG             55047 non-null  boolean
#  45  SEARCH_BASIS_CONSENT_FLAG               55047 non-null  boolean
#  46  SEARCH_BASIS_HARD_OBJECT_FLAG           55047 non-null  boolean
#  47  SEARCH_BASIS_INCIDENTAL_TO_ARREST_FLAG  55047 non-null  boolean
#  48  SEARCH_BASIS_OTHER_FLAG                 55047 non-null  boolean
#  49  SEARCH_BASIS_OUTLINE_FLAG               55047 non-null  boolean
#  50  SUSPECT_HEIGHT                          55047 non-null  Int64
#  51  STOP_FRISK_TIME                         55047 non-null  int64
#  52  lat                                     55047 non-null  float64
#  53  lon                                     55047 non-null  float64
#  54  geometry                                55047 non-null  geometry
#  55  index_right                             55047 non-null  float64
#  56  shape_area                              55047 non-null  object
#  57  NEIGHBORHOOD                            55047 non-null  object
#  58  cdtaname                                55047 non-null  object
#  59  shape_leng                              55047 non-null  object
#  60  boroname                                55047 non-null  object
#  61  ntatype                                 55047 non-null  object
#  62  nta2020                                 55047 non-null  object
#  63  borocode                                55047 non-null  object
#  64  countyfips                              55047 non-null  object
#  65  ntaabbrev                               55047 non-null  object
#  66  cdta2020                                55047 non-null  object
#  67  OUTCOME_OF_STOP                         55047 non-null  object
#  68  OFFICER_USED_FORCE                      55047 non-null  bool
#  69  FORCE_TYPE                              55047 non-null  object
# dtypes: Int64(8), bool(1), boolean(28), datetime64[ns](1), float64(3), geometry(1), int64(1), object(27)
# memory usage: 20.6+ MB
