# %%
# Import all the things...
import pandas as pd
from pathlib import Path
from utils.data_processing import (
    clean_data,
    null_strings,
    is_valid_child,
    column_categories,
    geocode_df,
    validate_neighborhood_data,
    prepare_additional_features,
    standardize_dates
)

# %%
# null_strings = ['(null)','#N/A', 'NA', '?', '', ' ', '&&', 'nan']

path = Path('./data/raw')
csv_files = path.glob('*.csv')

raw_df = pd.concat((pd.read_csv(f,dtype={
        'STOP_FRISK_DATE': 'object',  # Keep as string
        'STOP_FRISK_TIME': 'object'   # Keep as string
    },
    na_values=null_strings,  # Standardize nulls
    low_memory=False) for f in csv_files), ignore_index=True)
raw_df.head()
print(f"There are {len(raw_df)} records before cleaning")
# Out:
# There are 66406 records before cleaning

# %%
# Usage example:
raw_df['STOP_FRISK_DATE'] = raw_df['STOP_FRISK_DATE'].apply(standardize_dates)
raw_df[raw_df['YEAR2'] == 2022]
# Out:
#        STOP_ID STOP_FRISK_DATE STOP_FRISK_TIME  YEAR2    MONTH2      DAY2  \
# 51304        1      2022-01-01         8:40:00   2022   January  Saturday
# 51305        2      2022-01-01         3:25:00   2022   January  Saturday
# 51306        3      2022-01-01         0:19:00   2022   January  Saturday
# 51307        4      2022-01-01         3:00:00   2022   January  Saturday
# 51308        5      2022-01-01         3:00:00   2022   January  Saturday
# ...        ...             ...             ...    ...       ...       ...
# 66401    15098      2022-12-31        17:09:00   2022  December  Saturday
# 66402    15099      2022-12-31         4:00:00   2022  December  Saturday
# 66403    15100      2022-12-31         2:28:00   2022  December  Saturday
# 66404    15101      2022-12-31        20:25:00   2022  December  Saturday
# 66405    15102      2022-12-31        20:25:00   2022  December  Saturday
#
#             STOP_WAS_INITIATED RECORD_STATUS_CODE ISSUING_OFFICER_RANK  \
# 51304  Based on Self Initiated                APP                  POM
# 51305  Based on Self Initiated                APP                  POM
# 51306  Based on Self Initiated                APP                  POF
# 51307       Based on Radio Run                APP                  POM
# 51308       Based on Radio Run                APP                  POM
# ...                        ...                ...                  ...
# 66401  Based on Self Initiated                APP                  POM
# 66402       Based on Radio Run                APP                  POM
# 66403  Based on Self Initiated                APP                  POM
# 66404       Based on Radio Run                APP                  POM
# 66405       Based on Radio Run                APP                  POM
#
#        ISSUING_OFFICER_COMMAND_CODE  ... SUSPECT_OTHER_DESCRIPTION  \
# 51304                            73  ...                       NaN
# 51305                           183  ...                       NaN
# 51306                            52  ...                       NaN
# 51307                             9  ...                       NaN
# 51308                             9  ...                       NaN
# ...                             ...  ...                       ...
# 66401                           808  ...                       NaN
# 66402                            42  ...                       NaN
# 66403                           115  ...                       NaN
# 66404                            44  ...                       NaN
# 66405                            44  ...                       NaN
#
#        STOP_LOCATION_PRECINCT STOP_LOCATION_SECTOR_CODE  \
# 51304                    73.0                         C
# 51305                    42.0                         A
# 51306                    42.0                         A
# 51307                     9.0                         A
# 51308                     9.0                         A
# ...                       ...                       ...
# 66401                    43.0                         A
# 66402                    42.0                         D
# 66403                   115.0                         D
# 66404                    44.0                         E
# 66405                    44.0                         E
#
#       STOP_LOCATION_APARTMENT         STOP_LOCATION_FULL_ADDRESS  \
# 51304                     NaN  LIVONIA AVENUE && THATFORD AVENUE
# 51305                     NaN         WASHINGTON AVE && E 171 ST
# 51306                     NaN               E 170 ST && PARK AVE
# 51307                     NaN                 AVENUE A && E 1 ST
# 51308                     NaN                 AVENUE A && E 1 ST
# ...                       ...                                ...
# 66401                     NaN    RANDALL AVE && COMMONWEALTH AVE
# 66402                     NaN              E 163 ST && EAGLE AVE
# 66403                     NaN                        37-11 94 ST
# 66404                     NaN                  1310 SHERIDAN AVE
# 66405                     NaN                  1310 SHERIDAN AVE
#
#       STOP_LOCATION_STREET_NAME  STOP_LOCATION_X STOP_LOCATION_Y  \
# 51304            LIVONIA AVENUE        1008275.0        183622.0
# 51305            WASHINGTON AVE        1010997.0        244468.0
# 51306                  E 170 ST        1010321.0        243768.0
# 51307                  AVENUE A         988051.0        202409.0
# 51308                  AVENUE A         988051.0        202409.0
# ...                         ...              ...             ...
# 66401               RANDALL AVE        1021687.0        236876.0
# 66402                  E 163 ST        1009784.0        239429.0
# 66403                     94 ST        1019464.0        212685.0
# 66404              SHERIDAN AVE        1008017.0        244068.0
# 66405              SHERIDAN AVE        1008017.0        244068.0
#
#        STOP_LOCATION_PATROL_BORO_NAME STOP_LOCATION_BORO_NAME
# 51304                            PBBN                BROOKLYN
# 51305                            PBBX                   BRONX
# 51306                            PBBX                   BRONX
# 51307                            PBMS               MANHATTAN
# 51308                            PBMS               MANHATTAN
# ...                               ...                     ...
# 66401                            PBBX                   BRONX
# 66402                            PBBX                   BRONX
# 66403                            PBQN                  QUEENS
# 66404                            PBBX                   BRONX
# 66405                            PBBX                   BRONX
#
# [15102 rows x 83 columns]

# %%
cleaned_df = clean_data(raw_df, column_categories)
print(f'Approximately {(len(cleaned_df)/ len(raw_df)*100):.2f}% of the original data after cleaning')


plausible_df = cleaned_df[
    (cleaned_df.apply(is_valid_child, axis=1))
]
print(f'{(len(plausible_df) / len(cleaned_df)*100):.2f}% of data remains after age-height validation of children')
# Out:
# Approximately 83.02% of the original data after cleaning
# 99.96% of data remains after age-height validation of children

# %%
geocoded_df = geocode_df(plausible_df)
# Out:
# NTA CRS: EPSG:4326
# Stops GDF CRS: EPSG:4326
# NTA CRS: EPSG:4326
# Sample of transformed coordinates:
#          lat        lon
# 0  40.832167 -73.893445
# 1  40.672714 -73.753920
# 3  40.680767 -73.906721
# 4  40.812541 -73.955302
# 5  40.833561 -73.895933
# Points outside expected NYC bounds: 20
# Unmatched points: 26 out of 55073 (0.05%)
# Unmatched points remaining after cleaning: 0 out of 55047 (0.00%)

# %%
validate_neighborhood_data(geocoded_df)
# Out:
# Warning: No validation rule for Holy Cross Cemetery
# Warning: No validation rule for St. Michael's Cemetery
# Warning: No validation rule for Mount Olivet & All Faiths Cemeteries
# Warning: No validation rule for Rockaway Community Park
# Warning: No validation rule for Ferry Point Park-St. Raymond Cemetery
# All neighborhood-borough mappings validated successfully!
# Unique missing NTAs: {'Rockaway Community Park', 'Mount Olivet & All Faiths Cemeteries', 'Ferry Point Park-St. Raymond Cemetery', 'Holy Cross Cemetery', "St. Michael's Cemetery"}
# Found 23 borough name mismatches:
#       STOP_ID                                ntaname STOP_LOCATION_BORO_NAME  \
# 590       591                Howard Beach-Lindenwood                BROOKLYN
# 1993     1994                             Ozone Park                BROOKLYN
# 1994     1995                             Ozone Park                BROOKLYN
# 4126     4127                        Bushwick (East)                  QUEENS
# 4919     4920  Flatbush (West)-Ditmas Park-Parkville                  QUEENS
#
#       boroname
# 590     Queens
# 1993    Queens
# 1994    Queens
# 4126  Brooklyn
# 4919  Brooklyn
# After cleaning: Found 0 borough name mismatches:
# Empty DataFrame
# Columns: [STOP_ID, ntaname, STOP_LOCATION_BORO_NAME, boroname]
# Index: []

# %%
final_df = prepare_additional_features(geocoded_df)
final_df
# Out:
# OUTCOME_OF_STOP
# No Charges Filed    34939
# Arrested            18501
# Summoned             1607
# Name: count, dtype: int64
# OFFICER_USED_FORCE
# False                 41203
# True                  13844
# Name: count, dtype: int64
# FORCE_TYPE
# No Force                41203
# Handcuffs                8891
# Firearm Drawn            2184
# Restraint Used           1241
# Other Physical Force     1199
# Taser                     303
# Weapon Impact              21
# Pepper Spray                5
# Name: count, dtype: int64
#           STOP_FRISK_DATE  YEAR2  STOP_ID  OBSERVED_DURATION_MINUTES  \
# 0     2021-01-01 00:01:00   2021        1                          0
# 1     2021-01-01 00:01:00   2021        2                          1
# 2     2021-01-01 00:01:00   2021        4                          1
# 3     2021-01-01 00:01:00   2021        5                          1
# 4     2021-01-01 00:01:00   2021        6                          0
# ...                   ...    ...      ...                        ...
# 55042 2022-01-31 00:12:00   2022    15098                          1
# 55043 2022-01-31 00:12:00   2022    15099                          0
# 55044 2022-01-31 00:12:00   2022    15100                          1
# 55045 2022-01-31 00:12:00   2022    15101                          1
# 55046 2022-01-31 00:12:00   2022    15102                          1
#
#        STOP_DURATION_MINUTES  SUSPECT_REPORTED_AGE  SUSPECT_WEIGHT  \
# 0                          2                    40             200
# 1                         10                    19             160
# 2                          5                    28             180
# 3                         30                    19             185
# 4                          6                    32             160
# ...                      ...                   ...             ...
# 55042                      7                    45             250
# 55043                      1                    36            <NA>
# 55044                      2                    32             160
# 55045                      1                    18             150
# 55046                      1                    18             150
#
#        STOP_LOCATION_X  STOP_LOCATION_Y    MONTH2  ...   boroname ntatype  \
# 0              1013737           242476   January  ...      Bronx       0
# 1              1052511           184460   January  ...     Queens       0
# 2              1010122           187312   January  ...   Brooklyn       0
# 3               996623           235311   January  ...  Manhattan       0
# 4              1013048           242983   January  ...      Bronx       0
# ...                ...              ...       ...  ...        ...     ...
# 55042          1021687           236876  December  ...      Bronx       0
# 55043          1009784           239429  December  ...      Bronx       0
# 55044          1019464           212685  December  ...     Queens       0
# 55045          1008017           244068  December  ...      Bronx       0
# 55046          1008017           244068  December  ...      Bronx       0
#
#       nta2020 borocode countyfips   ntaabbrev cdta2020   OUTCOME_OF_STOP  \
# 0      BX0303        2        005  CrtnaPkEst     BX03          Arrested
# 1      QN1305        4        081       Lrltn     QN13          Arrested
# 2      BK1601        3        047       OcnHl     BK16  No Charges Filed
# 3      MN0901        1        061   MrngsdHts     MN09  No Charges Filed
# 4      BX0303        2        005  CrtnaPkEst     BX03          Arrested
# ...       ...      ...        ...         ...      ...               ...
# 55042  BX0902        2        005  Sdvw_ClsPt     BX09  No Charges Filed
# 55043  BX0301        2        005     Mrrsnia     BX03  No Charges Filed
# 55044  QN0301        4        081    JcksnHts     QN03  No Charges Filed
# 55045  BX0403        2        005       MtEdn     BX04  No Charges Filed
# 55046  BX0403        2        005       MtEdn     BX04  No Charges Filed
#
#       OFFICER_USED_FORCE FORCE_TYPE
# 0                   True  Handcuffs
# 1                  False   No Force
# 2                  False   No Force
# 3                   True  Handcuffs
# 4                  False   No Force
# ...                  ...        ...
# 55042              False   No Force
# 55043              False   No Force
# 55044              False   No Force
# 55045              False   No Force
# 55046              False   No Force
#
# [55047 rows x 71 columns]

# %%
first_type = type(final_df['STOP_FRISK_DATE'].iloc[0])
mixed_rows = final_df[final_df['STOP_FRISK_DATE'].apply(lambda x: type(x)) != first_type]
print(f"# of mixed rows: {len(mixed_rows)}")
mixed_rows.head()
# Out:
# # of mixed rows: 0
# Empty GeoDataFrame
# Columns: [STOP_FRISK_DATE, YEAR2, STOP_ID, OBSERVED_DURATION_MINUTES, STOP_DURATION_MINUTES, SUSPECT_REPORTED_AGE, SUSPECT_WEIGHT, STOP_LOCATION_X, STOP_LOCATION_Y, MONTH2, STOP_WAS_INITIATED, ISSUING_OFFICER_RANK, SUPERVISING_OFFICER_RANK, JURISDICTION_DESCRIPTION, SUSPECT_ARREST_OFFENSE, SUMMONS_OFFENSE_DESCRIPTION, SUSPECTED_CRIME_DESCRIPTION, DEMEANOR_OF_PERSON_STOPPED, SUSPECT_SEX, SUSPECT_RACE_DESCRIPTION, SUSPECT_BODY_BUILD_TYPE, SUSPECT_OTHER_DESCRIPTION, STOP_LOCATION_BORO_NAME, OFFICER_EXPLAINED_STOP_FLAG, OTHER_PERSON_STOPPED_FLAG, SUSPECT_ARRESTED_FLAG, SUMMONS_ISSUED_FLAG, OFFICER_IN_UNIFORM_FLAG, FRISKED_FLAG, SEARCHED_FLAG, ASK_FOR_CONSENT_FLG, CONSENT_GIVEN_FLG, OTHER_CONTRABAND_FLAG, FIREARM_FLAG, KNIFE_CUTTER_FLAG, OTHER_WEAPON_FLAG, WEAPON_FOUND_FLAG, PHYSICAL_FORCE_CEW_FLAG, PHYSICAL_FORCE_DRAW_POINT_FIREARM_FLAG, PHYSICAL_FORCE_HANDCUFF_SUSPECT_FLAG, PHYSICAL_FORCE_OC_SPRAY_USED_FLAG, PHYSICAL_FORCE_OTHER_FLAG, PHYSICAL_FORCE_RESTRAINT_USED_FLAG, PHYSICAL_FORCE_VERBAL_INSTRUCTION_FLAG, PHYSICAL_FORCE_WEAPON_IMPACT_FLAG, SEARCH_BASIS_ADMISSION_FLAG, SEARCH_BASIS_CONSENT_FLAG, SEARCH_BASIS_HARD_OBJECT_FLAG, SEARCH_BASIS_INCIDENTAL_TO_ARREST_FLAG, SEARCH_BASIS_OTHER_FLAG, SEARCH_BASIS_OUTLINE_FLAG, SUSPECT_HEIGHT, STOP_FRISK_TIME, lat, lon, geometry, index_right, shape_area, NEIGHBORHOOD, cdtaname, shape_leng, boroname, ntatype, nta2020, borocode, countyfips, ntaabbrev, cdta2020, OUTCOME_OF_STOP, OFFICER_USED_FORCE, FORCE_TYPE]
# Index: []
#
# [0 rows x 71 columns]

# %%
final_df = final_df.dropna(subset=['STOP_FRISK_DATE'])
final_df.to_csv('./data/processed/stop-and-frisk.csv', index=False)
final_df.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 55047 entries, 0 to 55046
# Data columns (total 71 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   STOP_FRISK_DATE                         55047 non-null  datetime64[ns]
#  1   YEAR2                                   55047 non-null  Int64
#  2   STOP_ID                                 55047 non-null  Int64
#  3   OBSERVED_DURATION_MINUTES               55047 non-null  Int64
#  4   STOP_DURATION_MINUTES                   55047 non-null  Int64
#  5   SUSPECT_REPORTED_AGE                    55047 non-null  Int64
#  6   SUSPECT_WEIGHT                          54113 non-null  Int64
#  7   STOP_LOCATION_X                         55047 non-null  Int64
#  8   STOP_LOCATION_Y                         55047 non-null  Int64
#  9   MONTH2                                  55047 non-null  object
#  10  STOP_WAS_INITIATED                      55047 non-null  object
#  11  ISSUING_OFFICER_RANK                    55047 non-null  object
#  12  SUPERVISING_OFFICER_RANK                53393 non-null  object
#  13  JURISDICTION_DESCRIPTION                30174 non-null  object
#  14  SUSPECT_ARREST_OFFENSE                  18501 non-null  object
#  15  SUMMONS_OFFENSE_DESCRIPTION             1829 non-null   object
#  16  SUSPECTED_CRIME_DESCRIPTION             55047 non-null  object
#  17  DEMEANOR_OF_PERSON_STOPPED              48311 non-null  object
#  18  SUSPECT_SEX                             54922 non-null  object
#  19  SUSPECT_RACE_DESCRIPTION                55047 non-null  object
#  20  SUSPECT_BODY_BUILD_TYPE                 53993 non-null  object
#  21  SUSPECT_OTHER_DESCRIPTION               21660 non-null  object
#  22  STOP_LOCATION_BORO_NAME                 55047 non-null  object
#  23  OFFICER_EXPLAINED_STOP_FLAG             55047 non-null  boolean
#  24  OTHER_PERSON_STOPPED_FLAG               55047 non-null  boolean
#  25  SUSPECT_ARRESTED_FLAG                   55047 non-null  boolean
#  26  SUMMONS_ISSUED_FLAG                     55047 non-null  boolean
#  27  OFFICER_IN_UNIFORM_FLAG                 55047 non-null  boolean
#  28  FRISKED_FLAG                            55047 non-null  boolean
#  29  SEARCHED_FLAG                           55047 non-null  boolean
#  30  ASK_FOR_CONSENT_FLG                     54201 non-null  boolean
#  31  CONSENT_GIVEN_FLG                       45655 non-null  boolean
#  32  OTHER_CONTRABAND_FLAG                   55047 non-null  boolean
#  33  FIREARM_FLAG                            55047 non-null  boolean
#  34  KNIFE_CUTTER_FLAG                       55047 non-null  boolean
#  35  OTHER_WEAPON_FLAG                       55047 non-null  boolean
#  36  WEAPON_FOUND_FLAG                       55047 non-null  boolean
#  37  PHYSICAL_FORCE_CEW_FLAG                 55047 non-null  boolean
#  38  PHYSICAL_FORCE_DRAW_POINT_FIREARM_FLAG  55047 non-null  boolean
#  39  PHYSICAL_FORCE_HANDCUFF_SUSPECT_FLAG    55047 non-null  boolean
#  40  PHYSICAL_FORCE_OC_SPRAY_USED_FLAG       55047 non-null  boolean
#  41  PHYSICAL_FORCE_OTHER_FLAG               55047 non-null  boolean
#  42  PHYSICAL_FORCE_RESTRAINT_USED_FLAG      55047 non-null  boolean
#  43  PHYSICAL_FORCE_VERBAL_INSTRUCTION_FLAG  55047 non-null  boolean
#  44  PHYSICAL_FORCE_WEAPON_IMPACT_FLAG       55047 non-null  boolean
#  45  SEARCH_BASIS_ADMISSION_FLAG             55047 non-null  boolean
#  46  SEARCH_BASIS_CONSENT_FLAG               55047 non-null  boolean
#  47  SEARCH_BASIS_HARD_OBJECT_FLAG           55047 non-null  boolean
#  48  SEARCH_BASIS_INCIDENTAL_TO_ARREST_FLAG  55047 non-null  boolean
#  49  SEARCH_BASIS_OTHER_FLAG                 55047 non-null  boolean
#  50  SEARCH_BASIS_OUTLINE_FLAG               55047 non-null  boolean
#  51  SUSPECT_HEIGHT                          55047 non-null  Int64
#  52  STOP_FRISK_TIME                         55047 non-null  int64
#  53  lat                                     55047 non-null  float64
#  54  lon                                     55047 non-null  float64
#  55  geometry                                55047 non-null  geometry
#  56  index_right                             55047 non-null  float64
#  57  shape_area                              55047 non-null  object
#  58  NEIGHBORHOOD                            55047 non-null  object
#  59  cdtaname                                55047 non-null  object
#  60  shape_leng                              55047 non-null  object
#  61  boroname                                55047 non-null  object
#  62  ntatype                                 55047 non-null  object
#  63  nta2020                                 55047 non-null  object
#  64  borocode                                55047 non-null  object
#  65  countyfips                              55047 non-null  object
#  66  ntaabbrev                               55047 non-null  object
#  67  cdta2020                                55047 non-null  object
#  68  OUTCOME_OF_STOP                         55047 non-null  object
#  69  OFFICER_USED_FORCE                      55047 non-null  bool
#  70  FORCE_TYPE                              55047 non-null  object
# dtypes: Int64(9), bool(1), boolean(28), datetime64[ns](1), float64(3), geometry(1), int64(1), object(27)
# memory usage: 21.1+ MB
